# %% [markdown]
# Data Types and Structures Questions

# %%
"""
1. What are data structures, and why are they important?
Answer:- Data structures are ways to organize and store data so it can be accessed and modified efficiently.
         They are important because they determine how fast and efficiently programs can perform oprtations like search, insert, delete, and sort.

2. Explain the difference between mutable and immutable data types with examples.
Answer:- 1) Mutable: Can be changed after creation (e.g. lis, dict, set)
         2) Immutable: Cannot be changed after creation (e.g. tuple, str, int)
         Mutable
        lst = [1, 2]
        lst.append(3)  # works

         Immutable
        t = (1, 2)
        t[0] = 3  # Error

3. What are the main differences between lists and tuples in Python?
Answer:- Lists: Mutable, slower, use square brackets [].

         Tuples: Immutable, faster, use parentheses ().

4. Describe how dictionaries store data.
Answer:- To store data as key-value pairs using a hash table, where each key's hash determines its storage location for quick lookup

5. Why might use a set instead of a list in python?
Answer:- To store unique elements and perform fast membership tests (in operator) and set operations (union, intersection)

6. What is a string in python and how it is different from the list?
Answer:- A string is an immutable sequence of charachters, whereas list is mutable sequence that can store different data types.

7. How tuples ensure data integrity in python?
Answer:- Tuples are immutable, meaning data can't be altered after creation, which prevents accidental modifications.

8. Wht is hash table, and how does it relate to dictionaries in pyton?
Answer:- A hash table is data structure that maps keys to values using a hash function. Python dictionaries use hash tables for fast lookups,

9. Can list conatin different data types in python?
Answer:- Yes. Example- My_list - [1, "hello", 3.14, True]

10. Explain why strings are immutable in python?
Answer:- Strings are immutable to improve performance, security, and hashing consistency when used as dictionary keys.

11. Waht advantages do dictionaries offer over lists for certain tasks?
Answer:- Dictionaries provide O(1) average time lookups using keys, making them faster for retrieving values when you know the key.

12. Describe a scenario where using a tuple would be preferable over a list.
Asnwer:- When storing fixed configuration values (e.g. GPS coordinates) that shouldn't change

13. How do sets handle duplicate values in Python?
Answer:- Sets automatically remove duplicates, keeping only unique elements.

14. How does then "in" keyword work differently for lists and dictionaries?
Answer:- 1) List: Checks if a value exists.

         2) Dictionary: Checks if a key exists (not the value).

15. Can you modify the elements of a tuple? Explain why and why not
Asnwer:- No, because tuples are immutable - you'd need to create a new tuple.

16. What is nested dictionary, and give an example of its use case?
Answer:- A dictionary containing another dictionary.
         Example:
         students = {
          "John" : {"age": 20, "grade": "A"},
          "Alice": {"age": 22, "grade": "B"}
         }
         Useful for stroing structured data like database record.

17. Describe the time complexity of accessing elements in a dictionary.
Answer:- 1) Average Case: O(1) (Constant Time) due to hashing
         2) Worst Case: O(1) if many hash collisions occur.

18. In what situations are list prefferable over dictionaries?
Asnwer:- When order matters, duplicates are needed, or you only have values without unique keys.

19. Why are dictionaries considered unordered, and how does that affect data retrieval?
Answer:- Before python 3.7, dictionaries didn't gurantee insertion order. This meant retrieval order could differ from insertion order.

20. Explain the difference between a list and a dictionary in terms of data retrieval.
Answer:- 1) List: Retrive by index (position).
         2) Dictionary: Retrieve by key (label).
"""

# %% [markdown]
# Practical Questions

# %%
# 1
name = "Rohan Ram Jware"
print("1: ",name)

# 2
print("2: ", len("Hello World"))

# 3
word =  "Python Programming"
print("3: ", word[:3])

#4
print("4: ", "hello".upper())

#5
print("5: ", "I like apple".replace("apple","orange"))

#6
number = [1, 2, 3, 4, 5]
print("6: ", number)

#7
numbers = [1, 2, 3, 4]
numbers.append(10)
print("7: ", numbers)

#8
l1 =  [1, 2, 3, 4, 5]
l1.remove(3)
print("8: ", l1)

#9
l2 =  ['a', 'b', 'c', 'd']
m = l2[1]
print("9: ", m)

#10
l3 =  [10, 20, 30, 40, 50]
print("10:",l3[::-1])

#11
tup = (100,200,300)
print("11:",tup)

#12
tup1 =  ('red', 'green', 'blue', 'yellow')
print("12:", tup1[1:])

#13
tup2 = (10, 20, 5, 15)
print("13:", min(tup2))

#14
tup3 = ('dog', 'cat', 'rabbit')
print("14:", tup3.index("cat"))

#15
fruits = ("apple", "kiwi", "dragonfruit")
print("15:", "kiwi" in fruits)

#16
s = {'a', 'b', 'c'}
print("16:",s)

#17
s1 = {1, 2, 3, 4, 5}
s1.clear()
print("17:", s1)

#18
s2 =  {1, 2, 3, 4}
s2.remove(4)
print("18:", s2)

#19
set1 = {1, 2, 3}
set2 = {3, 4, 5}
print("19:",set1.union(set2))

#20
set1 = {1, 2, 3}
set2 = {2, 3, 4}
print("20:",set1.intersection(set2))

#21
d1 = {"name":"Rohan Ram Jware",
      "age": 22,
      "city": "Thane"
}
print("21:", d1)

#22
d2 = {'name': 'John', 'age': 25}
d2["country"]="USA"
print("22:", d2)

#23
d3 = {'name': 'Alice', 'age': 30}
print("23:", d3['name'])

#24
d4 =  {'name': 'Bob', 'age': 22, 'city': 'New York'}
d4.pop('age')
print("24:", d4)

#25
d5 =  {'name': 'Alice', 'city': 'Paris'}
print("25:", 'city' in d5)

#26
l99 = [1, 2, 3]
tup22 = (4, 5, 6)
d68 = {'a': 1, 'b': 2}
print("26:", l99, tup22, d68)

#27
import random
n = random.sample(range(1, 101), 5)
n.sort()
print("27:", n)

#28
lst00 = ["apple", "banana", "cherry", "date"]
print("28:",lst00[3])

#29
d61 = {'a': 1, 'b': 2}
d62 = {'c': 3, 'd': 4}
d61.update(d62)
print("29:",d61)

#30
lst181 = ["apple", "banana", "apple", "cherry"]
print("30:",set(lst181))
# Out:
# 1:  Rohan Ram Jware
# 2:  11
# 3:  Pyt
# 4:  HELLO
# 5:  I like orange
# 6:  [1, 2, 3, 4, 5]
# 7:  [1, 2, 3, 4, 10]
# 8:  [1, 2, 4, 5]
# 9:  b
# 10: [50, 40, 30, 20, 10]
# 11: (100, 200, 300)
# 12: ('green', 'blue', 'yellow')
# 13: 5
# 14: 1
# 15: True
# 16: {'a', 'c', 'b'}
# 17: set()
# 18: {1, 2, 3}
# 19: {1, 2, 3, 4, 5}
# 20: {2, 3}
# 21: {'name': 'Rohan Ram Jware', 'age': 22, 'city': 'Thane'}
# 22: {'name': 'John', 'age': 25, 'country': 'USA'}
# 23: Alice
# 24: {'name': 'Bob', 'city': 'New York'}
# 25: True
# 26: [1, 2, 3] (4, 5, 6) {'a': 1, 'b': 2}
# 27: [52, 69, 80, 82, 88]
# 28: date
# 29: {'a': 1, 'b': 2, 'c': 3, 'd': 4}
# 30: {'banana', 'apple', 'cherry'}
